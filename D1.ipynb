# %% [markdown]
# # Part 1 Instructions
# --- Day 1: Secret Entrance ---
#
# The Elves have good news and bad news.
#
# The good news is that they've discovered project management! This has given them the tools they need to prevent their usual Christmas emergency. For example, they now know that the North Pole decorations need to be finished soon so that other critical tasks can start on time.
#
# The bad news is that they've realized they have a different emergency: according to their resource planning, none of them have any time left to decorate the North Pole!
#
# To save Christmas, the Elves need you to finish decorating the North Pole by December 12th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You arrive at the secret entrance to the North Pole base ready to start decorating. Unfortunately, the password seems to have been changed, so you can't get in. A document taped to the wall helpfully explains:
#
# "Due to new security protocols, the password is locked in the safe below. Please see the attached document for the new combination."
#
# The safe has a dial with only an arrow on it; around the dial are the numbers 0 through 99 in order. As you turn the dial, it makes a small click noise as it reaches each number.
#
# The attached document (your puzzle input) contains a sequence of rotations, one per line, which tell you how to open the safe. A rotation starts with an L or R which indicates whether the rotation should be to the left (toward lower numbers) or to the right (toward higher numbers). Then, the rotation has a distance value which indicates how many clicks the dial should be rotated in that direction.
#
# So, if the dial were pointing at 11, a rotation of R8 would cause the dial to point at 19. After that, a rotation of L19 would cause it to point at 0.
#
# Because the dial is a circle, turning the dial left from 0 one click makes it point at 99. Similarly, turning the dial right from 99 one click makes it point at 0.
#
# So, if the dial were pointing at 5, a rotation of L10 would cause it to point at 95. After that, a rotation of R5 could cause it to point at 0.
#
# The dial starts by pointing at 50.
#
# You could follow the instructions, but your recent required official North Pole secret entrance security training seminar taught you that the safe is actually a decoy. The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.
#
# For example, suppose the attached document contained the following rotations:
#
# L68
# L30
# R48
# L5
# R60
# L55
# L1
# L99
# R14
# L82
#
# Following these rotations would cause the dial to move as follows:
#
#     The dial starts by pointing at 50.
#     The dial is rotated L68 to point at 82.
#     The dial is rotated L30 to point at 52.
#     The dial is rotated R48 to point at 0.
#     The dial is rotated L5 to point at 95.
#     The dial is rotated R60 to point at 55.
#     The dial is rotated L55 to point at 0.
#     The dial is rotated L1 to point at 99.
#     The dial is rotated L99 to point at 0.
#     The dial is rotated R14 to point at 14.
#     The dial is rotated L82 to point at 32.
#
# Because the dial points at 0 a total of three times during this process, the password in this example is 3.
#
# Analyze the rotations in your attached document. What's the actual password to open the door?

# %% [markdown]
# GOAL: count the nubmer of times the dial points at zero by processing the long list of directions.
#
#
# INPUT: a text file with dial turn directions separated by new lines.
#
# STRATEGY: The rotation can be easily represented using modulo division by 100:
# - Create a function that takes an input string and the current number, and returns the resulting number after rotation (using modulo 100)
# - loop through all the lines in the file, and keep track with an integer

# %%
def rotate_dial(p:int, r:str):
    #returns the new number that the dial is pointing at after the rotation
    sign = 1 if r[0]=='R' else -1
    value = int(r[1:])
    return (p+sign*value)%100

rotate_dial(0, 'R100')
# Out:
# 0

# %%
dial = 50 #the dial starts at 50
n=0 #keep track of number of zeroes
m=0 #keep track of number of lines

#'r' means only open to read the file
with open('D1 input.txt', 'r') as f:
    for line in f:
        dial = rotate_dial(dial, line)
        m+=1
        if dial ==0:
            n+=1

print(n,m)
# Out:
# 1118 4424

# %% [markdown]
# # Part 2 Instructions
#
# You're sure that's the right password, but the door won't open. You knock, but nobody answers. You build a snowman while you think.
#
# As you're rolling the snowballs for your snowman, you find another security document that must have fallen into the snow:
#
# "Due to newer security protocols, please use password method 0x434C49434B until further notice."
#
# You remember from the training seminar that "method 0x434C49434B" means you're actually supposed to count the number of times any click causes the dial to point at 0, regardless of whether it happens during a rotation or at the end of one.
#
# Following the same rotations as in the above example, the dial points at zero a few extra times during its rotations:
#
#     The dial starts by pointing at 50.
#     The dial is rotated L68 to point at 82; during this rotation, it points at 0 once.
#     The dial is rotated L30 to point at 52.
#     The dial is rotated R48 to point at 0.
#     The dial is rotated L5 to point at 95.
#     The dial is rotated R60 to point at 55; during this rotation, it points at 0 once.
#     The dial is rotated L55 to point at 0.
#     The dial is rotated L1 to point at 99.
#     The dial is rotated L99 to point at 0.
#     The dial is rotated R14 to point at 14.
#     The dial is rotated L82 to point at 32; during this rotation, it points at 0 once.
#
# In this example, the dial points at 0 three times at the end of a rotation, plus three more times during a rotation. So, in this example, the new password would be 6.
#
# Be careful: if the dial were pointing at 50, a single rotation like R1000 would cause the dial to point at 0 ten times before returning back to 50!
#
# Using password method 0x434C49434B, what is the password to open the door?

# %% [markdown]
# STRATEGY: we can use floor division to keep track of the number of full rotations, and then use logic to keep track of the effect of the remaining fraction:
# - if rotation is left and the final dial number is larger than it started, add one to the zero count, unless it started on zero.
# - vice versa for a rightwards rotation.

# %%
n=0
old_dial = 50

dir = ['L68', 'L30', 'R48', 'L5', 'R60', 'L55', 'L1', 'L99', 'R14', 'L82']

for line in dir:
    print(f'dial starts at {old_dial}')
    print(f'rotating {line}')
    rot=int(line[1:])//100 #add the number of full rotations
    print(f'after {rot} full rotations and a little more')
    n+=rot
    new_dial = rotate_dial(old_dial, line)
    
     #check to see if the dial crossed zero
    if line[0]=='R' and new_dial < old_dial: 
        print('the dial was rotated right to or past zero')
        n+=1
    if line[0]=='L' and (new_dial > old_dial or new_dial==0) and old_dial != 0:
        print('the dial was rotated left to or past zero')
        n+=1
    print(f'the number of zeroes is {n}\n')
    old_dial=new_dial
       

print(n)
# Out:
# dial starts at 50
# rotating L68
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 1
#
# dial starts at 82
# rotating L30
# after 0 full rotations and a little more
# the number of zeroes is 1
#
# dial starts at 52
# rotating R48
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 2
#
# dial starts at 0
# rotating L5
# after 0 full rotations and a little more
# the number of zeroes is 2
#
# dial starts at 95
# rotating R60
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 3
#
# dial starts at 55
# rotating L55
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 4
#
# dial starts at 0
# rotating L1
# after 0 full rotations and a little more
# the number of zeroes is 4
#
# dial starts at 99
# rotating L99
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 5
#
# dial starts at 0
# rotating R14
# after 0 full rotations and a little more
# the number of zeroes is 5
#
# dial starts at 14
# rotating L82
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6
#
# 6

# %%
old_dial = 50 #the dial starts at 50
n=0 #keep track of number of zeroes

#'r' means only open to read the file
with open('D1 input.txt', 'r') as f:
    for line in f:
        print(f'dial starts at {old_dial}')
        print(f'rotating {line}')
        rot=int(line[1:])//100 #add the number of full rotations
        print(f'after {rot} full rotations and a little more')
        n+=rot
        new_dial = rotate_dial(old_dial, line)
        
            #check to see if the dial crossed zero
        if line[0]=='R' and new_dial < old_dial: 
            print('the dial was rotated right to or past zero')
            n+=1
        if line[0]=='L' and (new_dial > old_dial or new_dial==0) and old_dial != 0:
            print('the dial was rotated left to or past zero')
            n+=1
        print(f'the number of zeroes is {n}\n')
        old_dial=new_dial
       

print(n)
# Out:
# dial starts at 50
# rotating R45
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 95
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 53
# rotating R24
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 77
# rotating L11
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 66
# rotating R31
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 97
# rotating L19
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 78
# rotating R13
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 91
# rotating L30
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 61
# rotating R8
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 69
# rotating R21
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 90
# rotating L13
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 77
# rotating L23
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 54
# rotating R10
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 64
# rotating R19
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 83
# rotating L12
#
# after 0 full rotations and a little more
# the number of zeroes is 0
#
# dial starts at 71
# rotating R30
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 1
#
# dial starts at 1
# rotating L15
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 2
#
# dial starts at 86
# rotating R32
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 3
#
# dial starts at 18
# rotating R18
#
# after 0 full rotations and a little more
# the number of zeroes is 3
#
# dial starts at 36
# rotating R22
#
# after 0 full rotations and a little more
# the number of zeroes is 3
#
# dial starts at 58
# rotating L35
#
# after 0 full rotations and a little more
# the number of zeroes is 3
#
# dial starts at 23
# rotating R20
#
# after 0 full rotations and a little more
# the number of zeroes is 3
#
# dial starts at 43
# rotating L11
#
# after 0 full rotations and a little more
# the number of zeroes is 3
#
# dial starts at 32
# rotating L47
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 4
#
# dial starts at 85
# rotating L36
#
# after 0 full rotations and a little more
# the number of zeroes is 4
#
# dial starts at 49
# rotating L44
#
# after 0 full rotations and a little more
# the number of zeroes is 4
#
# dial starts at 5
# rotating L6
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 5
#
# dial starts at 99
# rotating R34
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6
#
# dial starts at 33
# rotating L46
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 7
#
# dial starts at 87
# rotating L38
#
# after 0 full rotations and a little more
# the number of zeroes is 7
#
# dial starts at 49
# rotating L45
#
# after 0 full rotations and a little more
# the number of zeroes is 7
#
# dial starts at 4
# rotating L7
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 8
#
# dial starts at 97
# rotating L41
#
# after 0 full rotations and a little more
# the number of zeroes is 8
#
# dial starts at 56
# rotating R22
#
# after 0 full rotations and a little more
# the number of zeroes is 8
#
# dial starts at 78
# rotating L30
#
# after 0 full rotations and a little more
# the number of zeroes is 8
#
# dial starts at 48
# rotating R44
#
# after 0 full rotations and a little more
# the number of zeroes is 8
#
# dial starts at 92
# rotating R30
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 9
#
# dial starts at 22
# rotating L15
#
# after 0 full rotations and a little more
# the number of zeroes is 9
#
# dial starts at 7
# rotating L22
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 10
#
# dial starts at 85
# rotating R43
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 11
#
# dial starts at 28
# rotating R48
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 76
# rotating L17
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 59
# rotating L22
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 37
# rotating R35
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 72
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 30
# rotating R7
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 37
# rotating R31
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 68
# rotating L38
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 30
# rotating R15
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 45
# rotating L39
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 6
# rotating R12
#
# after 0 full rotations and a little more
# the number of zeroes is 11
#
# dial starts at 18
# rotating L20
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 12
#
# dial starts at 98
# rotating R64
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 13
#
# dial starts at 62
# rotating L62
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 14
#
# dial starts at 0
# rotating L59
#
# after 0 full rotations and a little more
# the number of zeroes is 14
#
# dial starts at 41
# rotating R20
#
# after 0 full rotations and a little more
# the number of zeroes is 14
#
# dial starts at 61
# rotating R12
#
# after 0 full rotations and a little more
# the number of zeroes is 14
#
# dial starts at 73
# rotating R73
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 15
#
# dial starts at 46
# rotating R54
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 16
#
# dial starts at 0
# rotating L36
#
# after 0 full rotations and a little more
# the number of zeroes is 16
#
# dial starts at 64
# rotating L64
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 17
#
# dial starts at 0
# rotating L51
#
# after 0 full rotations and a little more
# the number of zeroes is 17
#
# dial starts at 49
# rotating L49
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 18
#
# dial starts at 0
# rotating R40
#
# after 0 full rotations and a little more
# the number of zeroes is 18
#
# dial starts at 40
# rotating L90
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 19
#
# dial starts at 50
# rotating R50
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 20
#
# dial starts at 0
# rotating R59
#
# after 0 full rotations and a little more
# the number of zeroes is 20
#
# dial starts at 59
# rotating R41
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 21
#
# dial starts at 0
# rotating R82
#
# after 0 full rotations and a little more
# the number of zeroes is 21
#
# dial starts at 82
# rotating R36
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 22
#
# dial starts at 18
# rotating L94
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 23
#
# dial starts at 24
# rotating R59
#
# after 0 full rotations and a little more
# the number of zeroes is 23
#
# dial starts at 83
# rotating R17
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 24
#
# dial starts at 0
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 24
#
# dial starts at 58
# rotating R42
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 25
#
# dial starts at 0
# rotating R58
#
# after 0 full rotations and a little more
# the number of zeroes is 25
#
# dial starts at 58
# rotating R42
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 26
#
# dial starts at 0
# rotating L6
#
# after 0 full rotations and a little more
# the number of zeroes is 26
#
# dial starts at 94
# rotating L40
#
# after 0 full rotations and a little more
# the number of zeroes is 26
#
# dial starts at 54
# rotating L55
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 27
#
# dial starts at 99
# rotating L17
#
# after 0 full rotations and a little more
# the number of zeroes is 27
#
# dial starts at 82
# rotating L9
#
# after 0 full rotations and a little more
# the number of zeroes is 27
#
# dial starts at 73
# rotating L97
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 28
#
# dial starts at 76
# rotating L76
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 29
#
# dial starts at 0
# rotating R78
#
# after 0 full rotations and a little more
# the number of zeroes is 29
#
# dial starts at 78
# rotating R22
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 30
#
# dial starts at 0
# rotating R19
#
# after 0 full rotations and a little more
# the number of zeroes is 30
#
# dial starts at 19
# rotating L70
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 31
#
# dial starts at 49
# rotating R59
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 32
#
# dial starts at 8
# rotating L21
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 33
#
# dial starts at 87
# rotating L92
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 34
#
# dial starts at 95
# rotating L35
#
# after 0 full rotations and a little more
# the number of zeroes is 34
#
# dial starts at 60
# rotating L33
#
# after 0 full rotations and a little more
# the number of zeroes is 34
#
# dial starts at 27
# rotating L91
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 35
#
# dial starts at 36
# rotating L59
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 36
#
# dial starts at 77
# rotating L77
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 37
#
# dial starts at 0
# rotating L77
#
# after 0 full rotations and a little more
# the number of zeroes is 37
#
# dial starts at 23
# rotating L71
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 38
#
# dial starts at 52
# rotating L21
#
# after 0 full rotations and a little more
# the number of zeroes is 38
#
# dial starts at 31
# rotating R78
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 39
#
# dial starts at 9
# rotating L72
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 40
#
# dial starts at 37
# rotating R963
#
# after 9 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 50
#
# dial starts at 0
# rotating R77
#
# after 0 full rotations and a little more
# the number of zeroes is 50
#
# dial starts at 77
# rotating L2
#
# after 0 full rotations and a little more
# the number of zeroes is 50
#
# dial starts at 75
# rotating L412
#
# after 4 full rotations and a little more
# the number of zeroes is 54
#
# dial starts at 63
# rotating L661
#
# after 6 full rotations and a little more
# the number of zeroes is 60
#
# dial starts at 2
# rotating R397
#
# after 3 full rotations and a little more
# the number of zeroes is 63
#
# dial starts at 99
# rotating R11
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 64
#
# dial starts at 10
# rotating R835
#
# after 8 full rotations and a little more
# the number of zeroes is 72
#
# dial starts at 45
# rotating R55
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 73
#
# dial starts at 0
# rotating L19
#
# after 0 full rotations and a little more
# the number of zeroes is 73
#
# dial starts at 81
# rotating L93
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 74
#
# dial starts at 88
# rotating R88
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 75
#
# dial starts at 76
# rotating R544
#
# after 5 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 81
#
# dial starts at 20
# rotating R21
#
# after 0 full rotations and a little more
# the number of zeroes is 81
#
# dial starts at 41
# rotating L39
#
# after 0 full rotations and a little more
# the number of zeroes is 81
#
# dial starts at 2
# rotating L88
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 82
#
# dial starts at 14
# rotating L91
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 83
#
# dial starts at 23
# rotating R777
#
# after 7 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 91
#
# dial starts at 0
# rotating R72
#
# after 0 full rotations and a little more
# the number of zeroes is 91
#
# dial starts at 72
# rotating R28
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 92
#
# dial starts at 0
# rotating L127
#
# after 1 full rotations and a little more
# the number of zeroes is 93
#
# dial starts at 73
# rotating L73
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 94
#
# dial starts at 0
# rotating L72
#
# after 0 full rotations and a little more
# the number of zeroes is 94
#
# dial starts at 28
# rotating R72
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 95
#
# dial starts at 0
# rotating L5
#
# after 0 full rotations and a little more
# the number of zeroes is 95
#
# dial starts at 95
# rotating R3
#
# after 0 full rotations and a little more
# the number of zeroes is 95
#
# dial starts at 98
# rotating R2
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 96
#
# dial starts at 0
# rotating R86
#
# after 0 full rotations and a little more
# the number of zeroes is 96
#
# dial starts at 86
# rotating R966
#
# after 9 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 106
#
# dial starts at 52
# rotating R48
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 107
#
# dial starts at 0
# rotating R56
#
# after 0 full rotations and a little more
# the number of zeroes is 107
#
# dial starts at 56
# rotating R56
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 108
#
# dial starts at 12
# rotating R88
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 109
#
# dial starts at 0
# rotating L8
#
# after 0 full rotations and a little more
# the number of zeroes is 109
#
# dial starts at 92
# rotating L892
#
# after 8 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 118
#
# dial starts at 0
# rotating L70
#
# after 0 full rotations and a little more
# the number of zeroes is 118
#
# dial starts at 30
# rotating R51
#
# after 0 full rotations and a little more
# the number of zeroes is 118
#
# dial starts at 81
# rotating L49
#
# after 0 full rotations and a little more
# the number of zeroes is 118
#
# dial starts at 32
# rotating L33
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 119
#
# dial starts at 99
# rotating R98
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 120
#
# dial starts at 97
# rotating L97
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 121
#
# dial starts at 0
# rotating L37
#
# after 0 full rotations and a little more
# the number of zeroes is 121
#
# dial starts at 63
# rotating L96
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 122
#
# dial starts at 67
# rotating L62
#
# after 0 full rotations and a little more
# the number of zeroes is 122
#
# dial starts at 5
# rotating R15
#
# after 0 full rotations and a little more
# the number of zeroes is 122
#
# dial starts at 20
# rotating L120
#
# after 1 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 124
#
# dial starts at 0
# rotating L299
#
# after 2 full rotations and a little more
# the number of zeroes is 126
#
# dial starts at 1
# rotating R77
#
# after 0 full rotations and a little more
# the number of zeroes is 126
#
# dial starts at 78
# rotating L78
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 127
#
# dial starts at 0
# rotating L4
#
# after 0 full rotations and a little more
# the number of zeroes is 127
#
# dial starts at 96
# rotating R13
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 128
#
# dial starts at 9
# rotating R23
#
# after 0 full rotations and a little more
# the number of zeroes is 128
#
# dial starts at 32
# rotating L32
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 129
#
# dial starts at 0
# rotating R94
#
# after 0 full rotations and a little more
# the number of zeroes is 129
#
# dial starts at 94
# rotating L28
#
# after 0 full rotations and a little more
# the number of zeroes is 129
#
# dial starts at 66
# rotating L979
#
# after 9 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 139
#
# dial starts at 87
# rotating R34
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 140
#
# dial starts at 21
# rotating L4
#
# after 0 full rotations and a little more
# the number of zeroes is 140
#
# dial starts at 17
# rotating L893
#
# after 8 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 149
#
# dial starts at 24
# rotating R51
#
# after 0 full rotations and a little more
# the number of zeroes is 149
#
# dial starts at 75
# rotating R59
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 150
#
# dial starts at 34
# rotating L534
#
# after 5 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 156
#
# dial starts at 0
# rotating R385
#
# after 3 full rotations and a little more
# the number of zeroes is 159
#
# dial starts at 85
# rotating R34
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 160
#
# dial starts at 19
# rotating L3
#
# after 0 full rotations and a little more
# the number of zeroes is 160
#
# dial starts at 16
# rotating R984
#
# after 9 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 170
#
# dial starts at 0
# rotating L690
#
# after 6 full rotations and a little more
# the number of zeroes is 176
#
# dial starts at 10
# rotating R837
#
# after 8 full rotations and a little more
# the number of zeroes is 184
#
# dial starts at 47
# rotating R53
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 185
#
# dial starts at 0
# rotating R40
#
# after 0 full rotations and a little more
# the number of zeroes is 185
#
# dial starts at 40
# rotating L40
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 186
#
# dial starts at 0
# rotating R52
#
# after 0 full rotations and a little more
# the number of zeroes is 186
#
# dial starts at 52
# rotating L77
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 187
#
# dial starts at 75
# rotating L75
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 188
#
# dial starts at 0
# rotating L99
#
# after 0 full rotations and a little more
# the number of zeroes is 188
#
# dial starts at 1
# rotating R79
#
# after 0 full rotations and a little more
# the number of zeroes is 188
#
# dial starts at 80
# rotating L292
#
# after 2 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 191
#
# dial starts at 88
# rotating L94
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 192
#
# dial starts at 94
# rotating R6
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 193
#
# dial starts at 0
# rotating L317
#
# after 3 full rotations and a little more
# the number of zeroes is 196
#
# dial starts at 83
# rotating L946
#
# after 9 full rotations and a little more
# the number of zeroes is 205
#
# dial starts at 37
# rotating R63
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 206
#
# dial starts at 0
# rotating L620
#
# after 6 full rotations and a little more
# the number of zeroes is 212
#
# dial starts at 80
# rotating R20
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 213
#
# dial starts at 0
# rotating R2
#
# after 0 full rotations and a little more
# the number of zeroes is 213
#
# dial starts at 2
# rotating L2
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 214
#
# dial starts at 0
# rotating L17
#
# after 0 full rotations and a little more
# the number of zeroes is 214
#
# dial starts at 83
# rotating L83
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 215
#
# dial starts at 0
# rotating R16
#
# after 0 full rotations and a little more
# the number of zeroes is 215
#
# dial starts at 16
# rotating R21
#
# after 0 full rotations and a little more
# the number of zeroes is 215
#
# dial starts at 37
# rotating L1
#
# after 0 full rotations and a little more
# the number of zeroes is 215
#
# dial starts at 36
# rotating R64
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 216
#
# dial starts at 0
# rotating L98
#
# after 0 full rotations and a little more
# the number of zeroes is 216
#
# dial starts at 2
# rotating R98
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 217
#
# dial starts at 0
# rotating R84
#
# after 0 full rotations and a little more
# the number of zeroes is 217
#
# dial starts at 84
# rotating L84
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 218
#
# dial starts at 0
# rotating R159
#
# after 1 full rotations and a little more
# the number of zeroes is 219
#
# dial starts at 59
# rotating L22
#
# after 0 full rotations and a little more
# the number of zeroes is 219
#
# dial starts at 37
# rotating L701
#
# after 7 full rotations and a little more
# the number of zeroes is 226
#
# dial starts at 36
# rotating R8
#
# after 0 full rotations and a little more
# the number of zeroes is 226
#
# dial starts at 44
# rotating L49
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 227
#
# dial starts at 95
# rotating L77
#
# after 0 full rotations and a little more
# the number of zeroes is 227
#
# dial starts at 18
# rotating L18
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 228
#
# dial starts at 0
# rotating R74
#
# after 0 full rotations and a little more
# the number of zeroes is 228
#
# dial starts at 74
# rotating R918
#
# after 9 full rotations and a little more
# the number of zeroes is 237
#
# dial starts at 92
# rotating L92
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 238
#
# dial starts at 0
# rotating R95
#
# after 0 full rotations and a little more
# the number of zeroes is 238
#
# dial starts at 95
# rotating L95
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 239
#
# dial starts at 0
# rotating R61
#
# after 0 full rotations and a little more
# the number of zeroes is 239
#
# dial starts at 61
# rotating L1
#
# after 0 full rotations and a little more
# the number of zeroes is 239
#
# dial starts at 60
# rotating L249
#
# after 2 full rotations and a little more
# the number of zeroes is 241
#
# dial starts at 11
# rotating L81
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 242
#
# dial starts at 30
# rotating L9
#
# after 0 full rotations and a little more
# the number of zeroes is 242
#
# dial starts at 21
# rotating L77
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 243
#
# dial starts at 44
# rotating L40
#
# after 0 full rotations and a little more
# the number of zeroes is 243
#
# dial starts at 4
# rotating R90
#
# after 0 full rotations and a little more
# the number of zeroes is 243
#
# dial starts at 94
# rotating R75
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 244
#
# dial starts at 69
# rotating L58
#
# after 0 full rotations and a little more
# the number of zeroes is 244
#
# dial starts at 11
# rotating L11
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 245
#
# dial starts at 0
# rotating L46
#
# after 0 full rotations and a little more
# the number of zeroes is 245
#
# dial starts at 54
# rotating L28
#
# after 0 full rotations and a little more
# the number of zeroes is 245
#
# dial starts at 26
# rotating R74
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 246
#
# dial starts at 0
# rotating R35
#
# after 0 full rotations and a little more
# the number of zeroes is 246
#
# dial starts at 35
# rotating R65
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 247
#
# dial starts at 0
# rotating L50
#
# after 0 full rotations and a little more
# the number of zeroes is 247
#
# dial starts at 50
# rotating L50
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 248
#
# dial starts at 0
# rotating R22
#
# after 0 full rotations and a little more
# the number of zeroes is 248
#
# dial starts at 22
# rotating L25
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 249
#
# dial starts at 97
# rotating R74
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 250
#
# dial starts at 71
# rotating R628
#
# after 6 full rotations and a little more
# the number of zeroes is 256
#
# dial starts at 99
# rotating L97
#
# after 0 full rotations and a little more
# the number of zeroes is 256
#
# dial starts at 2
# rotating R8
#
# after 0 full rotations and a little more
# the number of zeroes is 256
#
# dial starts at 10
# rotating R890
#
# after 8 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 265
#
# dial starts at 0
# rotating L8
#
# after 0 full rotations and a little more
# the number of zeroes is 265
#
# dial starts at 92
# rotating R979
#
# after 9 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 275
#
# dial starts at 71
# rotating R29
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 276
#
# dial starts at 0
# rotating L97
#
# after 0 full rotations and a little more
# the number of zeroes is 276
#
# dial starts at 3
# rotating R5
#
# after 0 full rotations and a little more
# the number of zeroes is 276
#
# dial starts at 8
# rotating R49
#
# after 0 full rotations and a little more
# the number of zeroes is 276
#
# dial starts at 57
# rotating L357
#
# after 3 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 280
#
# dial starts at 0
# rotating R73
#
# after 0 full rotations and a little more
# the number of zeroes is 280
#
# dial starts at 73
# rotating L86
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 281
#
# dial starts at 87
# rotating L60
#
# after 0 full rotations and a little more
# the number of zeroes is 281
#
# dial starts at 27
# rotating R73
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 282
#
# dial starts at 0
# rotating L83
#
# after 0 full rotations and a little more
# the number of zeroes is 282
#
# dial starts at 17
# rotating L17
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 283
#
# dial starts at 0
# rotating L90
#
# after 0 full rotations and a little more
# the number of zeroes is 283
#
# dial starts at 10
# rotating L95
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 284
#
# dial starts at 15
# rotating R843
#
# after 8 full rotations and a little more
# the number of zeroes is 292
#
# dial starts at 58
# rotating R42
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 293
#
# dial starts at 0
# rotating L96
#
# after 0 full rotations and a little more
# the number of zeroes is 293
#
# dial starts at 4
# rotating L82
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 294
#
# dial starts at 22
# rotating R90
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 295
#
# dial starts at 12
# rotating L12
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 296
#
# dial starts at 0
# rotating L78
#
# after 0 full rotations and a little more
# the number of zeroes is 296
#
# dial starts at 22
# rotating R78
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 297
#
# dial starts at 0
# rotating R78
#
# after 0 full rotations and a little more
# the number of zeroes is 297
#
# dial starts at 78
# rotating L767
#
# after 7 full rotations and a little more
# the number of zeroes is 304
#
# dial starts at 11
# rotating R269
#
# after 2 full rotations and a little more
# the number of zeroes is 306
#
# dial starts at 80
# rotating L703
#
# after 7 full rotations and a little more
# the number of zeroes is 313
#
# dial starts at 77
# rotating L77
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 314
#
# dial starts at 0
# rotating L45
#
# after 0 full rotations and a little more
# the number of zeroes is 314
#
# dial starts at 55
# rotating L90
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 315
#
# dial starts at 65
# rotating L156
#
# after 1 full rotations and a little more
# the number of zeroes is 316
#
# dial starts at 9
# rotating L9
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 317
#
# dial starts at 0
# rotating L46
#
# after 0 full rotations and a little more
# the number of zeroes is 317
#
# dial starts at 54
# rotating L54
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 318
#
# dial starts at 0
# rotating L406
#
# after 4 full rotations and a little more
# the number of zeroes is 322
#
# dial starts at 94
# rotating L27
#
# after 0 full rotations and a little more
# the number of zeroes is 322
#
# dial starts at 67
# rotating R33
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 323
#
# dial starts at 0
# rotating R87
#
# after 0 full rotations and a little more
# the number of zeroes is 323
#
# dial starts at 87
# rotating L87
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 324
#
# dial starts at 0
# rotating L510
#
# after 5 full rotations and a little more
# the number of zeroes is 329
#
# dial starts at 90
# rotating L52
#
# after 0 full rotations and a little more
# the number of zeroes is 329
#
# dial starts at 38
# rotating R74
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 330
#
# dial starts at 12
# rotating R88
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 331
#
# dial starts at 0
# rotating L18
#
# after 0 full rotations and a little more
# the number of zeroes is 331
#
# dial starts at 82
# rotating L33
#
# after 0 full rotations and a little more
# the number of zeroes is 331
#
# dial starts at 49
# rotating R51
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 332
#
# dial starts at 0
# rotating R511
#
# after 5 full rotations and a little more
# the number of zeroes is 337
#
# dial starts at 11
# rotating R40
#
# after 0 full rotations and a little more
# the number of zeroes is 337
#
# dial starts at 51
# rotating R47
#
# after 0 full rotations and a little more
# the number of zeroes is 337
#
# dial starts at 98
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 337
#
# dial starts at 56
# rotating R60
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 338
#
# dial starts at 16
# rotating R5
#
# after 0 full rotations and a little more
# the number of zeroes is 338
#
# dial starts at 21
# rotating R79
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 339
#
# dial starts at 0
# rotating L56
#
# after 0 full rotations and a little more
# the number of zeroes is 339
#
# dial starts at 44
# rotating L91
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 340
#
# dial starts at 53
# rotating L53
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 341
#
# dial starts at 0
# rotating L59
#
# after 0 full rotations and a little more
# the number of zeroes is 341
#
# dial starts at 41
# rotating L150
#
# after 1 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 343
#
# dial starts at 91
# rotating L91
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 344
#
# dial starts at 0
# rotating R15
#
# after 0 full rotations and a little more
# the number of zeroes is 344
#
# dial starts at 15
# rotating L68
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 345
#
# dial starts at 47
# rotating R286
#
# after 2 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 348
#
# dial starts at 33
# rotating R60
#
# after 0 full rotations and a little more
# the number of zeroes is 348
#
# dial starts at 93
# rotating L472
#
# after 4 full rotations and a little more
# the number of zeroes is 352
#
# dial starts at 21
# rotating R67
#
# after 0 full rotations and a little more
# the number of zeroes is 352
#
# dial starts at 88
# rotating R12
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 353
#
# dial starts at 0
# rotating R39
#
# after 0 full rotations and a little more
# the number of zeroes is 353
#
# dial starts at 39
# rotating R61
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 354
#
# dial starts at 0
# rotating R69
#
# after 0 full rotations and a little more
# the number of zeroes is 354
#
# dial starts at 69
# rotating L69
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 355
#
# dial starts at 0
# rotating L63
#
# after 0 full rotations and a little more
# the number of zeroes is 355
#
# dial starts at 37
# rotating R897
#
# after 8 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 364
#
# dial starts at 34
# rotating R166
#
# after 1 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 366
#
# dial starts at 0
# rotating L70
#
# after 0 full rotations and a little more
# the number of zeroes is 366
#
# dial starts at 30
# rotating L30
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 367
#
# dial starts at 0
# rotating R169
#
# after 1 full rotations and a little more
# the number of zeroes is 368
#
# dial starts at 69
# rotating L69
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 369
#
# dial starts at 0
# rotating L991
#
# after 9 full rotations and a little more
# the number of zeroes is 378
#
# dial starts at 9
# rotating L9
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 379
#
# dial starts at 0
# rotating R13
#
# after 0 full rotations and a little more
# the number of zeroes is 379
#
# dial starts at 13
# rotating R81
#
# after 0 full rotations and a little more
# the number of zeroes is 379
#
# dial starts at 94
# rotating R504
#
# after 5 full rotations and a little more
# the number of zeroes is 384
#
# dial starts at 98
# rotating R31
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 385
#
# dial starts at 29
# rotating L53
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 386
#
# dial starts at 76
# rotating R98
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 387
#
# dial starts at 74
# rotating L374
#
# after 3 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 391
#
# dial starts at 0
# rotating R417
#
# after 4 full rotations and a little more
# the number of zeroes is 395
#
# dial starts at 17
# rotating L17
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 396
#
# dial starts at 0
# rotating L23
#
# after 0 full rotations and a little more
# the number of zeroes is 396
#
# dial starts at 77
# rotating R23
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 397
#
# dial starts at 0
# rotating R23
#
# after 0 full rotations and a little more
# the number of zeroes is 397
#
# dial starts at 23
# rotating L94
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 398
#
# dial starts at 29
# rotating L21
#
# after 0 full rotations and a little more
# the number of zeroes is 398
#
# dial starts at 8
# rotating R92
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 399
#
# dial starts at 0
# rotating R570
#
# after 5 full rotations and a little more
# the number of zeroes is 404
#
# dial starts at 70
# rotating L954
#
# after 9 full rotations and a little more
# the number of zeroes is 413
#
# dial starts at 16
# rotating R84
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 414
#
# dial starts at 0
# rotating R51
#
# after 0 full rotations and a little more
# the number of zeroes is 414
#
# dial starts at 51
# rotating R46
#
# after 0 full rotations and a little more
# the number of zeroes is 414
#
# dial starts at 97
# rotating L97
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 415
#
# dial starts at 0
# rotating R760
#
# after 7 full rotations and a little more
# the number of zeroes is 422
#
# dial starts at 60
# rotating R40
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 423
#
# dial starts at 0
# rotating L49
#
# after 0 full rotations and a little more
# the number of zeroes is 423
#
# dial starts at 51
# rotating R49
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 424
#
# dial starts at 0
# rotating L75
#
# after 0 full rotations and a little more
# the number of zeroes is 424
#
# dial starts at 25
# rotating R87
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 425
#
# dial starts at 12
# rotating R85
#
# after 0 full rotations and a little more
# the number of zeroes is 425
#
# dial starts at 97
# rotating R84
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 426
#
# dial starts at 81
# rotating L81
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 427
#
# dial starts at 0
# rotating R45
#
# after 0 full rotations and a little more
# the number of zeroes is 427
#
# dial starts at 45
# rotating R155
#
# after 1 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 429
#
# dial starts at 0
# rotating L23
#
# after 0 full rotations and a little more
# the number of zeroes is 429
#
# dial starts at 77
# rotating L40
#
# after 0 full rotations and a little more
# the number of zeroes is 429
#
# dial starts at 37
# rotating R28
#
# after 0 full rotations and a little more
# the number of zeroes is 429
#
# dial starts at 65
# rotating L8
#
# after 0 full rotations and a little more
# the number of zeroes is 429
#
# dial starts at 57
# rotating L966
#
# after 9 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 439
#
# dial starts at 91
# rotating L26
#
# after 0 full rotations and a little more
# the number of zeroes is 439
#
# dial starts at 65
# rotating R35
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 440
#
# dial starts at 0
# rotating R25
#
# after 0 full rotations and a little more
# the number of zeroes is 440
#
# dial starts at 25
# rotating R54
#
# after 0 full rotations and a little more
# the number of zeroes is 440
#
# dial starts at 79
# rotating R21
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 441
#
# dial starts at 0
# rotating L212
#
# after 2 full rotations and a little more
# the number of zeroes is 443
#
# dial starts at 88
# rotating L21
#
# after 0 full rotations and a little more
# the number of zeroes is 443
#
# dial starts at 67
# rotating R33
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 444
#
# dial starts at 0
# rotating R581
#
# after 5 full rotations and a little more
# the number of zeroes is 449
#
# dial starts at 81
# rotating L34
#
# after 0 full rotations and a little more
# the number of zeroes is 449
#
# dial starts at 47
# rotating R53
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 450
#
# dial starts at 0
# rotating R42
#
# after 0 full rotations and a little more
# the number of zeroes is 450
#
# dial starts at 42
# rotating L78
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 451
#
# dial starts at 64
# rotating L623
#
# after 6 full rotations and a little more
# the number of zeroes is 457
#
# dial starts at 41
# rotating R59
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 458
#
# dial starts at 0
# rotating L43
#
# after 0 full rotations and a little more
# the number of zeroes is 458
#
# dial starts at 57
# rotating L57
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 459
#
# dial starts at 0
# rotating L96
#
# after 0 full rotations and a little more
# the number of zeroes is 459
#
# dial starts at 4
# rotating L78
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 460
#
# dial starts at 26
# rotating L64
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 461
#
# dial starts at 62
# rotating R38
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 462
#
# dial starts at 0
# rotating R45
#
# after 0 full rotations and a little more
# the number of zeroes is 462
#
# dial starts at 45
# rotating L41
#
# after 0 full rotations and a little more
# the number of zeroes is 462
#
# dial starts at 4
# rotating R96
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 463
#
# dial starts at 0
# rotating L118
#
# after 1 full rotations and a little more
# the number of zeroes is 464
#
# dial starts at 82
# rotating L71
#
# after 0 full rotations and a little more
# the number of zeroes is 464
#
# dial starts at 11
# rotating L18
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 465
#
# dial starts at 93
# rotating R35
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 466
#
# dial starts at 28
# rotating R63
#
# after 0 full rotations and a little more
# the number of zeroes is 466
#
# dial starts at 91
# rotating L119
#
# after 1 full rotations and a little more
# the number of zeroes is 467
#
# dial starts at 72
# rotating L81
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 468
#
# dial starts at 91
# rotating L791
#
# after 7 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 476
#
# dial starts at 0
# rotating R88
#
# after 0 full rotations and a little more
# the number of zeroes is 476
#
# dial starts at 88
# rotating L277
#
# after 2 full rotations and a little more
# the number of zeroes is 478
#
# dial starts at 11
# rotating L957
#
# after 9 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 488
#
# dial starts at 54
# rotating R72
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 489
#
# dial starts at 26
# rotating R74
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 490
#
# dial starts at 0
# rotating R424
#
# after 4 full rotations and a little more
# the number of zeroes is 494
#
# dial starts at 24
# rotating R76
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 495
#
# dial starts at 0
# rotating L47
#
# after 0 full rotations and a little more
# the number of zeroes is 495
#
# dial starts at 53
# rotating L98
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 496
#
# dial starts at 55
# rotating R45
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 497
#
# dial starts at 0
# rotating R49
#
# after 0 full rotations and a little more
# the number of zeroes is 497
#
# dial starts at 49
# rotating R851
#
# after 8 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 506
#
# dial starts at 0
# rotating R90
#
# after 0 full rotations and a little more
# the number of zeroes is 506
#
# dial starts at 90
# rotating R14
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 507
#
# dial starts at 4
# rotating R19
#
# after 0 full rotations and a little more
# the number of zeroes is 507
#
# dial starts at 23
# rotating R99
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 508
#
# dial starts at 22
# rotating R2
#
# ...
# the number of zeroes is 6189
#
# dial starts at 0
# rotating R12
#
# after 0 full rotations and a little more
# the number of zeroes is 6189
#
# dial starts at 12
# rotating L812
#
# after 8 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6198
#
# dial starts at 0
# rotating R7
#
# after 0 full rotations and a little more
# the number of zeroes is 6198
#
# dial starts at 7
# rotating R867
#
# after 8 full rotations and a little more
# the number of zeroes is 6206
#
# dial starts at 74
# rotating L51
#
# after 0 full rotations and a little more
# the number of zeroes is 6206
#
# dial starts at 23
# rotating L209
#
# after 2 full rotations and a little more
# the number of zeroes is 6208
#
# dial starts at 14
# rotating L14
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6209
#
# dial starts at 0
# rotating R837
#
# after 8 full rotations and a little more
# the number of zeroes is 6217
#
# dial starts at 37
# rotating R75
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6218
#
# dial starts at 12
# rotating R88
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6219
#
# dial starts at 0
# rotating L57
#
# after 0 full rotations and a little more
# the number of zeroes is 6219
#
# dial starts at 43
# rotating R66
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6220
#
# dial starts at 9
# rotating L204
#
# after 2 full rotations and a little more
# the number of zeroes is 6222
#
# dial starts at 5
# rotating L89
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6223
#
# dial starts at 16
# rotating L676
#
# after 6 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6230
#
# dial starts at 40
# rotating L93
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6231
#
# dial starts at 47
# rotating L145
#
# after 1 full rotations and a little more
# the number of zeroes is 6232
#
# dial starts at 2
# rotating R53
#
# after 0 full rotations and a little more
# the number of zeroes is 6232
#
# dial starts at 55
# rotating R16
#
# after 0 full rotations and a little more
# the number of zeroes is 6232
#
# dial starts at 71
# rotating L71
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6233
#
# dial starts at 0
# rotating L485
#
# after 4 full rotations and a little more
# the number of zeroes is 6237
#
# dial starts at 15
# rotating L12
#
# after 0 full rotations and a little more
# the number of zeroes is 6237
#
# dial starts at 3
# rotating R197
#
# after 1 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6239
#
# dial starts at 0
# rotating R25
#
# after 0 full rotations and a little more
# the number of zeroes is 6239
#
# dial starts at 25
# rotating L11
#
# after 0 full rotations and a little more
# the number of zeroes is 6239
#
# dial starts at 14
# rotating R86
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6240
#
# dial starts at 0
# rotating L90
#
# after 0 full rotations and a little more
# the number of zeroes is 6240
#
# dial starts at 10
# rotating R17
#
# after 0 full rotations and a little more
# the number of zeroes is 6240
#
# dial starts at 27
# rotating R73
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6241
#
# dial starts at 0
# rotating R8
#
# after 0 full rotations and a little more
# the number of zeroes is 6241
#
# dial starts at 8
# rotating R92
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6242
#
# dial starts at 0
# rotating R33
#
# after 0 full rotations and a little more
# the number of zeroes is 6242
#
# dial starts at 33
# rotating R972
#
# after 9 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6252
#
# dial starts at 5
# rotating R90
#
# after 0 full rotations and a little more
# the number of zeroes is 6252
#
# dial starts at 95
# rotating L58
#
# after 0 full rotations and a little more
# the number of zeroes is 6252
#
# dial starts at 37
# rotating R92
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6253
#
# dial starts at 29
# rotating R83
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6254
#
# dial starts at 12
# rotating R88
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6255
#
# dial starts at 0
# rotating L22
#
# after 0 full rotations and a little more
# the number of zeroes is 6255
#
# dial starts at 78
# rotating R6
#
# after 0 full rotations and a little more
# the number of zeroes is 6255
#
# dial starts at 84
# rotating L84
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6256
#
# dial starts at 0
# rotating R62
#
# after 0 full rotations and a little more
# the number of zeroes is 6256
#
# dial starts at 62
# rotating L5
#
# after 0 full rotations and a little more
# the number of zeroes is 6256
#
# dial starts at 57
# rotating R37
#
# after 0 full rotations and a little more
# the number of zeroes is 6256
#
# dial starts at 94
# rotating R82
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6257
#
# dial starts at 76
# rotating R17
#
# after 0 full rotations and a little more
# the number of zeroes is 6257
#
# dial starts at 93
# rotating R96
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6258
#
# dial starts at 89
# rotating R11
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6259
#
# dial starts at 0
# rotating L29
#
# after 0 full rotations and a little more
# the number of zeroes is 6259
#
# dial starts at 71
# rotating R73
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6260
#
# dial starts at 44
# rotating L44
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6261
#
# dial starts at 0
# rotating R47
#
# after 0 full rotations and a little more
# the number of zeroes is 6261
#
# dial starts at 47
# rotating R53
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6262
#
# dial starts at 0
# rotating R97
#
# after 0 full rotations and a little more
# the number of zeroes is 6262
#
# dial starts at 97
# rotating L53
#
# after 0 full rotations and a little more
# the number of zeroes is 6262
#
# dial starts at 44
# rotating R76
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6263
#
# dial starts at 20
# rotating R25
#
# after 0 full rotations and a little more
# the number of zeroes is 6263
#
# dial starts at 45
# rotating L45
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6264
#
# dial starts at 0
# rotating R7
#
# after 0 full rotations and a little more
# the number of zeroes is 6264
#
# dial starts at 7
# rotating R39
#
# after 0 full rotations and a little more
# the number of zeroes is 6264
#
# dial starts at 46
# rotating R25
#
# after 0 full rotations and a little more
# the number of zeroes is 6264
#
# dial starts at 71
# rotating R29
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6265
#
# dial starts at 0
# rotating R44
#
# after 0 full rotations and a little more
# the number of zeroes is 6265
#
# dial starts at 44
# rotating R56
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6266
#
# dial starts at 0
# rotating R67
#
# after 0 full rotations and a little more
# the number of zeroes is 6266
#
# dial starts at 67
# rotating R35
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6267
#
# dial starts at 2
# rotating R92
#
# after 0 full rotations and a little more
# the number of zeroes is 6267
#
# dial starts at 94
# rotating L50
#
# after 0 full rotations and a little more
# the number of zeroes is 6267
#
# dial starts at 44
# rotating L68
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6268
#
# dial starts at 76
# rotating R93
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6269
#
# dial starts at 69
# rotating L69
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6270
#
# dial starts at 0
# rotating L52
#
# after 0 full rotations and a little more
# the number of zeroes is 6270
#
# dial starts at 48
# rotating R82
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6271
#
# dial starts at 30
# rotating R21
#
# after 0 full rotations and a little more
# the number of zeroes is 6271
#
# dial starts at 51
# rotating L47
#
# after 0 full rotations and a little more
# the number of zeroes is 6271
#
# dial starts at 4
# rotating R96
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6272
#
# dial starts at 0
# rotating L94
#
# after 0 full rotations and a little more
# the number of zeroes is 6272
#
# dial starts at 6
# rotating L8
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6273
#
# dial starts at 98
# rotating L37
#
# after 0 full rotations and a little more
# the number of zeroes is 6273
#
# dial starts at 61
# rotating L61
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6274
#
# dial starts at 0
# rotating R59
#
# after 0 full rotations and a little more
# the number of zeroes is 6274
#
# dial starts at 59
# rotating R16
#
# after 0 full rotations and a little more
# the number of zeroes is 6274
#
# dial starts at 75
# rotating L72
#
# after 0 full rotations and a little more
# the number of zeroes is 6274
#
# dial starts at 3
# rotating R97
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6275
#
# dial starts at 0
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 58
# rotating L37
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 21
# rotating R47
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 68
# rotating L1
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 67
# rotating L39
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 28
# rotating L14
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 14
# rotating L8
#
# after 0 full rotations and a little more
# the number of zeroes is 6275
#
# dial starts at 6
# rotating L8
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6276
#
# dial starts at 98
# rotating L3
#
# after 0 full rotations and a little more
# the number of zeroes is 6276
#
# dial starts at 95
# rotating R48
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6277
#
# dial starts at 43
# rotating L39
#
# after 0 full rotations and a little more
# the number of zeroes is 6277
#
# dial starts at 4
# rotating R3
#
# after 0 full rotations and a little more
# the number of zeroes is 6277
#
# dial starts at 7
# rotating L21
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6278
#
# dial starts at 86
# rotating L10
#
# after 0 full rotations and a little more
# the number of zeroes is 6278
#
# dial starts at 76
# rotating R35
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6279
#
# dial starts at 11
# rotating R25
#
# after 0 full rotations and a little more
# the number of zeroes is 6279
#
# dial starts at 36
# rotating L3
#
# after 0 full rotations and a little more
# the number of zeroes is 6279
#
# dial starts at 33
# rotating L19
#
# after 0 full rotations and a little more
# the number of zeroes is 6279
#
# dial starts at 14
# rotating R45
#
# after 0 full rotations and a little more
# the number of zeroes is 6279
#
# dial starts at 59
# rotating R28
#
# after 0 full rotations and a little more
# the number of zeroes is 6279
#
# dial starts at 87
# rotating R40
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6280
#
# dial starts at 27
# rotating L14
#
# after 0 full rotations and a little more
# the number of zeroes is 6280
#
# dial starts at 13
# rotating R14
#
# after 0 full rotations and a little more
# the number of zeroes is 6280
#
# dial starts at 27
# rotating L23
#
# after 0 full rotations and a little more
# the number of zeroes is 6280
#
# dial starts at 4
# rotating L38
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6281
#
# dial starts at 66
# rotating R42
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6282
#
# dial starts at 8
# rotating L22
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6283
#
# dial starts at 86
# rotating L29
#
# after 0 full rotations and a little more
# the number of zeroes is 6283
#
# dial starts at 57
# rotating L45
#
# after 0 full rotations and a little more
# the number of zeroes is 6283
#
# dial starts at 12
# rotating L46
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6284
#
# dial starts at 66
# rotating R39
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6285
#
# dial starts at 5
# rotating L22
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6286
#
# dial starts at 83
# rotating L37
#
# after 0 full rotations and a little more
# the number of zeroes is 6286
#
# dial starts at 46
# rotating L36
#
# after 0 full rotations and a little more
# the number of zeroes is 6286
#
# dial starts at 10
# rotating L33
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6287
#
# dial starts at 77
# rotating R46
#
# after 0 full rotations and a little more
# the dial was rotated right to or past zero
# the number of zeroes is 6288
#
# dial starts at 23
# rotating R32
#
# after 0 full rotations and a little more
# the number of zeroes is 6288
#
# dial starts at 55
# rotating R1
#
# after 0 full rotations and a little more
# the number of zeroes is 6288
#
# dial starts at 56
# rotating R17
#
# after 0 full rotations and a little more
# the number of zeroes is 6288
#
# dial starts at 73
# rotating L18
#
# after 0 full rotations and a little more
# the number of zeroes is 6288
#
# dial starts at 55
# rotating L42
#
# after 0 full rotations and a little more
# the number of zeroes is 6288
#
# dial starts at 13
# rotating L36
#
# after 0 full rotations and a little more
# the dial was rotated left to or past zero
# the number of zeroes is 6289
#
# dial starts at 77
# rotating R10
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 87
# rotating R4
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 91
# rotating L18
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 73
# rotating L26
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 47
# rotating L31
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 16
# rotating R26
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 42
# rotating R9
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# dial starts at 51
# rotating R48
#
# after 0 full rotations and a little more
# the number of zeroes is 6289
#
# 6289
